# %%
a = int(input("Nhập hệ số thứ nhất: "))
b = int(input("Nhập hệ số thứ hai: "))
c = int(input("Nhập hệ số thứ ba: "))

if a==1 or a==-1:
    if b==0:
        if c==0:
            print("Phương trình có dạng: x^2")
        elif c<0:
            print("Phương trình có dạng: x^2 {0}".format(c))
        else:
            print("Phương trình có dạng: x^2 + {0}".format(c))
    elif b>0:
        if c==0:
            print("Phương trình có dạng: x^2 + {0}x".format(b))
        elif c<0:
            print("Phương trình có dạng: x^2 + {0}x {1}".format(b,c))
        else:
            print("Phương trình có dạng: x^2 + {0}x + {1}".format(b,c))
    else:
        if c==0:
            print("Phương trình có dạng: x^2 {0}x".format(b))
        elif c<0:
            print("Phương trình có dạng: x^2 {0}x {1}".format(b,c))
        else:
            print("Phương trình có dạng: x^2 {0}x + {1}".format(b,c))
elif a>0 and a!=1:
    if b==0:
        if c==0:
            print("Phương trình có dạng: {0}x^2".format(a))
        elif c<0:
            print("Phương trình có dạng: {0}x^2 {1}".format(a,c))
        else:
            print("Phương trình có dạng: {0}x^2 + {1}".format(a,c))
    elif b>0:
        if c==0:
            print("Phương trình có dạng: {0}x^2 + {1}x".format(a,b))
        elif c<0:
            print("Phương trình có dạng: {0}x^2 + {1}x {2}".format(a,b,c))
        else:
            print("Phương trình có dạng: {0}x^2 + {1}x + {2}".format(a,b,c))
    else:
        if c==0:
            print("Phương trình có dạng: {0}x^2 {1}x".format(a,b))
        elif c<0:
            print("Phương trình có dạng: {0}x^2 {1}x {2}".format(a,b,c))
        else:
            print("Phương trình có dạng: {0}x^2 {1}x + {2}".format(a,b,c))
elif a<0 and a!=-1:
    if b==0:
        if c==0:
            print("Phương trình có dạng: ({0}x^2)".format(a))
        elif c<0:
            print("Phương trình có dạng: ({0}x^2) {1}".format(a,c))
        else:
            print("Phương trình có dạng: ({0}x^2) + {1}".format(a,c))
    elif b>0:
        if c==0:
            print("Phương trình có dạng: ({0}x^2) + {1}x".format(a,b))
        elif c<0:
            print("Phương trình có dạng: ({0}x^2) + {1}x {2}".format(a,b,c))
        else:
            print("Phương trình có dạng: ({0}x^2) + {1}x + {2}".format(a,b,c))
    else:
        if c==0:
            print("Phương trình có dạng: ({0}x^2) {1}x".format(a,b))
        elif c<0:
            print("Phương trình có dạng: ({0}x^2) {1}x {2}".format(a,b,c))
        else:
            print("Phương trình có dạng: ({0}x^2) {1}x + {2}".format(a,b,c))
elif a==0:
    if b==0:
        if c==0:
            print("Phương trình có dạng: 0".format(a))
        elif c<0:
            print("Phương trình có dạng: {0}".format(c))
        else:
            print("Phương trình có dạng: {0}".format(c))
    elif b>0:
        if c==0:
            print("Phương trình có dạng: {0}x".format(b))
        elif c<0:
            print("Phương trình có dạng: {0}x {1}".format(b,c))
        else:
            print("Phương trình có dạng: {0}x + {1}".format(b,c))
    else:
        if c==0:
            print("Phương trình có dạng: {0}x".format(b))
        elif c<0:
            print("Phương trình có dạng: {0}x {1}".format(b,c))
        else:
            print("Phương trình có dạng: {0}x + {1}".format(b,c))
else:
    print("lỗi")
# Out:
# Nhập hệ số thứ nhất: -4
# Nhập hệ số thứ hai: 6
# Nhập hệ số thứ ba: 7
# Hệ phương trình có dạng: (-4x^2) + 6x + 7
